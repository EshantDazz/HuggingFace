# %% [markdown]
# <a href="https://colab.research.google.com/github/EshantDazz/HuggingFace/blob/main/Transformers/Pipeline_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
import torch
from diffusers import DiffusionPipeline
from datasets import load_dataset
import soundfile as sf
from IPython.display import Audio

# %% [markdown]
# ## Sentiment Analysis

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
result=classifier("I am so happy")
result
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998812675476074}]

# %%
result=classifier("I am not happy to eat vegetables")
result
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9994926452636719}]

# %% [markdown]
# ## NER

# %%
ner=pipeline("ner", grouped_entities=True)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
result=ner("Barack Obama was the 44th president of United States of America")
result
# Out:
# [{'entity_group': 'PER',
#   'score': 0.9991052,
#   'word': 'Barack Obama',
#   'start': 0,
#   'end': 12},
#  {'entity_group': 'LOC',
#   'score': 0.9902936,
#   'word': 'United States of America',
#   'start': 39,
#   'end': 63}]

# %% [markdown]
# ## QuestionAnsweringwithContext

# %%
question_answering=pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
result=question_answering(question="Who is the prime minister of India",context="Modi is the Prime Minister of India")
result
# Out:
# {'score': 0.9903203248977661, 'start': 0, 'end': 4, 'answer': 'Modi'}

# %% [markdown]
# ## Text Summarisation

# %%
data="""
Cricket: The Gentleman's Game That Conquered Nations

Cricket, often called the gentleman's game, stands as one of the most intricate and cherished sports in the world. Born in the rolling fields of England during the 16th century, this bat-and-ball game has evolved from a simple pastoral pastime into a global phenomenon that ignites passion across continents, particularly in the nations of the former British Empire.

The modern game's charm lies in its rich complexity. At its heart, cricket is a contest between bat and ball, but this simple premise unfolds into a sophisticated tapestry of strategies, skills, and endurance. A cricket match can span from a few hours in its shortest format (T20) to five days in Test matches, the game's purest and most traditional form. This variety has helped cricket adapt to changing times while preserving its core essence.

Test cricket, often considered the pinnacle of the sport, is a true test of character, technique, and temperament. Players battle not just their opponents but also changing weather conditions, deteriorating pitch conditions, and their own physical and mental fatigue. A Test match is like a compelling drama that unfolds over five days, with momentum swinging like a pendulum between teams, creating narratives that cricket aficionados cherish for generations.

The advent of limited-overs cricket, particularly Twenty20 (T20), has revolutionized the sport. This format has injected new energy into cricket, attracting a younger audience with its fast-paced action and entertainment value. Tournaments like the Indian Premier League (IPL) have transformed cricket into a commercial powerhouse, where sports meets entertainment, creating a template that other cricket nations have eagerly followed.

Cricket's technical aspects are fascinatingly complex. The art of bowling, for instance, involves much more than simply hurling a ball. Fast bowlers must master variations in speed, movement, and bounce, while spin bowlers rely on flight, turn, and deception. Batting is equally nuanced, requiring a perfect blend of defense and aggression, alongside the ability to "read" the bowler's intentions and adapt to varying pitch conditions.

The sport has given rise to legendary figures whose achievements transcend cricket. Sir Donald Bradman's batting average of 99.94 stands as perhaps the most remarkable statistical achievement in any sport. The elegant West Indian Sir Vivian Richards, the masterful Sachin Tendulkar, the innovative Shane Warne, and the devastating Brian Lara have not just been cricketers but cultural icons who have inspired millions.

Cricket's influence extends beyond the boundary rope. In countries like India, Pakistan, and Bangladesh, it's not merely a sport but a unifying force that brings together diverse populations. Important matches can bring entire nations to a standstill. The India-Pakistan cricket rivalry, for instance, is often viewed as a diplomatic tool, with matches between these nations drawing global attention.

The game continues to evolve, embracing technology through the Decision Review System (DRS), which has added a new layer of fairness and drama to the sport. Cricket is also making strides in gender equality, with women's cricket gaining prominence and professional leagues being established worldwide.

Yet, cricket faces challenges. The balance between different formats, the preservation of Test cricket, and the need to expand beyond traditional strongholds are ongoing concerns. The sport must also address issues like match-fixing and the impact of year-round cricket on players' well-being.

Looking ahead, cricket's future seems bright but complex. The sport is gradually gaining ground in non-traditional markets, with efforts to include it in the Olympics. New formats and rules are being experimented with, while traditional aspects are being preserved. This balance between innovation and tradition will likely determine cricket's trajectory in the coming decades.

What makes cricket truly special is its ability to mirror life itself. Like life, it requires patience, perseverance, and the ability to weather both triumph and defeat with equal grace. It teaches valuable lessons about teamwork, leadership, and the importance of playing within the spirit of the game – qualities that resonate far beyond the cricket field.

In essence, cricket remains a unique sport that combines athletic skill, strategic thinking, and gentlemanly conduct. It's a game that has successfully retained its traditional charm while adapting to modern demands, ensuring its place in the hearts of millions around the world.


"""

# %%
summarizer=pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
summary=summarizer(data,max_length=50,min_length=25,do_sample=False)
summary
# Out:
# [{'summary_text': " Cricket: The Gentleman's Game That Conquered Nations is one of the most intricate and cherished sports in the world . At its heart, cricket is a contest between bat and ball, but this simple premise unfolds into a sophisticated tapest"}]

# %%
summary[0]['summary_text']
# Out:
# " Cricket: The Gentleman's Game That Conquered Nations is one of the most intricate and cherished sports in the world . At its heart, cricket is a contest between bat and ball, but this simple premise unfolds into a sophisticated tapest"

# %% [markdown]
# ## Translation

# %%
translator=pipeline("translation_en_to_fr")
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision a9723ea (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
result=translator("Data Science is very interesting")
result[0]['translation_text']
# Out:
# 'La science des données est très intéressante'

# %% [markdown]
# ## ClassifiCATION

# %%
classifier=pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...

# %%
result=classifier("Hugging face Transformers library is amazing",candidate_labels=["education","politics","sports","technology"])
result
# Out:
# {'sequence': 'Hugging face Transformers library is amazing',
#  'labels': ['technology', 'education', 'sports', 'politics'],
#  'scores': [0.888558566570282,
#   0.06174420937895775,
#   0.033609360456466675,
#   0.016087882220745087]}

# %% [markdown]
# ## Text Generation

# %%
generator=pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
result=generator("If there is 1 thing I would want you to rememeber about hugging face library then that is...")
result[0]["generated_text"]
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 'If there is 1 thing I would want you to rememeber about hugging face library then that is...the end of it." The two of us were both able to laugh and say that. They were both proud and looked at each other with that'

# %% [markdown]
# ## Image Audio and others

# %%
# Image Generation

image_gen = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2",
    torch_dtype=torch.float16,
    use_safetensors=True,
    variant="fp16"
    )

# %%
text = "A class of Data Scientists learning about AI, in the surreal style of Salvador Dali"
image = image_gen(prompt=text).images[0]
image

# %%
# Audio Generation

synthesiser = pipeline("text-to-speech", "microsoft/speecht5_tts", device='cuda')

embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
speaker_embedding = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

speech = synthesiser("Hi to an artificial intelligence engineer, on the way to mastery!", forward_params={"speaker_embeddings": speaker_embedding})

sf.write("speech.wav", speech["audio"], samplerate=speech["sampling_rate"])
Audio("speech.wav")
# Out:
# config.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/585M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/232 [00:00<?, ?B/s]
# spm_char.model:   0%|          | 0.00/238k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/433 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/50.7M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# cmu-arctic-xvectors.py:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/21.3M [00:00<?, ?B/s]
# Generating validation split:   0%|          | 0/7931 [00:00<?, ? examples/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
# ...

# %% [markdown]
# I'll break down this code which is using the Hugging Face transformers library for text-to-speech (TTS) generation:
#
# 1. First line creates the text-to-speech pipeline:
#
# pythonCopysynthesiser = pipeline("text-to-speech", "microsoft/speecht5_tts", device='cuda')
#
# - Uses the pipeline from Hugging Face transformers
# - Loads Microsoft's SpeechT5 TTS model
# - Runs on GPU (device='cuda')
#
#
# 2. Loading speaker embeddings:
#
# pythonCopyembeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
# speaker_embedding = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)
#
# - Loads a dataset containing voice characteristics (x-vectors)
# - Selects a specific voice embedding (index 7306)
# - Converts it to a PyTorch tensor and adds a batch dimension with unsqueeze(0)
#
#
# 3. Generating speech:
#
# pythonCopyspeech = synthesiser("Hi to an artificial intelligence engineer, on the way to mastery!",
#                     forward_params={"speaker_embeddings": speaker_embedding})
#
# - Takes the text input and generates audio
# - Uses the selected speaker embedding to determine voice characteristics
# - Returns a dictionary with the audio data and sampling rate
#
#
# 4. Saving and playing the audio:
#
# pythonCopysf.write("speech.wav", speech["audio"], samplerate=speech["sampling_rate"])
# Audio("speech.wav")
#
# - Saves the generated audio as a WAV file using soundfile (sf)
# - Plays the audio using IPython's Audio display (likely in a Jupyter notebook)
#
# The key innovation here is the use of speaker embeddings, which allow you to control voice characteristics. The CMU Arctic x-vectors dataset provides these embeddings, which capture things like pitch, tone, and speaking style from real speakers.
